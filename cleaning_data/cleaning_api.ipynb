# %% [markdown]
# # Nettoyage des données récupérées grâce à l'API de TMDB
#
# Dans cette partie nous allons nettoyer et clarifier les données récupérées grâce à l'API de TMDB. En effet, un certain nombre des variables ne nous intéresse pas, et d'autres variables sont formatées d'une certaine façon qui ne sera pas très pratique à exploiter telle quelle.
# Nous procèderons donc en deux parties, chacune assez rapide car les données récupérées sont déjà assez bien formatées.
# 1. **Supprimer les variables inutile**
# 2. **Clarifier les variables formatées de façon trop complexe**
#
# ## Étape 1 : Suppression des variables inutiles pour notre projet
#
# Nous allons donc commencer par garder uniquement les variables qui nous intéresse. Pour celà, nous regardons les noms des colonnes pour savoir à quoi chacune correspond, et ainsi savoir lesquelles nous intéresse ou non. Cette étape ne présente aucune difficulté particulière.

# %%
import pandas as pd
import re
import os
import ast

# %%
base = pd.read_csv('../API/MoviesPopDir.csv')
print(base.columns)
# Out:
# Index(['Unnamed: 0', 'adult', 'backdrop_path', 'belongs_to_collection',
#        'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'directors'],
#       dtype='object')

# %%
base = base.drop(['Unnamed: 0','backdrop_path','homepage', 'poster_path', 'video', 'status'], axis=1)

# %%
base
# Out:
#        adult                              belongs_to_collection     budget  \
# 0      False                                                NaN   40000000
# 1      False                                                NaN  200000000
# 2      False  {'id': 489724, 'name': 'The Trolls Collection'...   95000000
# 3      False                                                NaN          0
# 4      False                                                NaN  125000000
# ...      ...                                                ...        ...
# 12012  False  {'id': 124901, 'name': 'Hatchet Collection', '...          0
# 12013  False                                                NaN          0
# 12014  False  {'id': 8917, 'name': 'Hellraiser Collection', ...    4000000
# 12015  False                                                NaN   45000000
# 12016  False                                                NaN    1000000
#
#                                                   genres       id     imdb_id  \
# 0      [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...   897087  tt15744298
# 1      [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...   466420   tt5537002
# 2      [{'id': 16, 'name': 'Animation'}, {'id': 10751...   901362  tt14362112
# 3      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  1075794   tt5755238
# 4      [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...   787699   tt6166392
# ...                                                  ...      ...         ...
# 12012  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...   472338   tt5534434
# 12013  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...   605116   tt7550000
# 12014  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...    17455   tt0337636
# 12015  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...    15045   tt0396592
# 12016  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...      541   tt0048347
#
#       original_language               original_title  \
# 0                    en                    Freelance
# 1                    en   Killers of the Flower Moon
# 2                    en         Trolls Band Together
# 3                    en                          Leo
# 4                    en                        Wonka
# ...                 ...                          ...
# 12012                en               Victor Crowley
# 12013                en                Project Power
# 12014                en           Hellraiser: Deader
# 12015                en                   Fat Albert
# 12016                en  The Man with the Golden Arm
#
#                                                 overview popularity  ...  \
# 0      An ex-special forces operative takes a job to ...   2367.027  ...
# 1      When oil is discovered in 1920s Oklahoma under...   1806.389  ...
# 2      When Branch's brother, Floyd, is kidnapped for...   1560.713  ...
# 3      Jaded 74-year-old lizard Leo has been stuck in...    1303.89  ...
# 4      Willy Wonka – chock-full of ideas and determin...   1256.256  ...
# ...                                                  ...        ...  ...
# 12012  Ten years ago, over forty people were brutally...     30.668  ...
# 12013  An ex-soldier, a teen and a cop collide in New...      30.55  ...
# 12014  In London, after investigating crack addicted ...     30.664  ...
# 12015  Animated character Fat Albert emerges from his...     30.536  ...
# 12016  A junkie must face his true self to kick his d...     30.664  ...
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   2023-10-05
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   2023-10-18
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   2023-10-12
# 3      [{'iso_3166_1': 'AU', 'name': 'Australia'}, {'...   2023-11-17
# 4      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2023-12-06
# ...                                                  ...          ...
# 12012  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-09-12
# 12013  [{'iso_3166_1': 'US', 'name': 'United States o...   2020-08-14
# 12014  [{'iso_3166_1': 'RO', 'name': 'Romania'}, {'is...   2005-06-07
# 12015  [{'iso_3166_1': 'US', 'name': 'United States o...   2004-12-25
# 12016  [{'iso_3166_1': 'US', 'name': 'United States o...   1955-12-26
#
#            revenue  runtime  \
# 0        8000000.0    108.0
# 1      155500000.0    206.0
# 2      173800000.0     92.0
# 3              0.0    102.0
# 4       43200000.0    117.0
# ...            ...      ...
# 12012          0.0     83.0
# 12013          0.0    113.0
# 12014          0.0     88.0
# 12015   48600000.0     93.0
# 12016    4350000.0    119.0
#
#                                         spoken_languages  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...
# 2      [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      [{'english_name': 'English', 'iso_639_1': 'en'...
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...
# ...                                                  ...
# 12012  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12013  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12014  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12015  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12016  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                  tagline  \
# 0                            Retirement didn't suit him.
# 1             Greed is an animal that hungers for blood.
# 2                There are some new trolls on the block.
# 3                            Breaking out this November.
# 4      Every good thing in this world started with a ...
# ...                                                  ...
# 12012                                Return to his Swamp
# 12013  What would you risk for five minutes of pure p...
# 12014                  The Latest. Most Terrifying Evil.
# 12015                                     Hey! Hey! Hey!
# 12016  An 'untouchable' theme…an unusual motion picture!
#
#                              title vote_average  vote_count  \
# 0                        Freelance        6.419       192.0
# 1       Killers of the Flower Moon        7.711      1258.0
# 2             Trolls Band Together        7.204       324.0
# 3                              Leo        7.560       497.0
# 4                            Wonka        7.000        62.0
# ...                            ...          ...         ...
# 12012               Victor Crowley        5.700       235.0
# 12013                Project Power        6.474      2666.0
# 12014           Hellraiser: Deader        4.600       292.0
# 12015                   Fat Albert        5.100       242.0
# 12016  The Man with the Golden Arm        7.200       200.0
#
#                                                directors
# 0                                       ['Pierre Morel']
# 1                                    ['Martin Scorsese']
# 2                                         ['Walt Dohrn']
# 3      ['Robert Smigel', 'Robert Marianetti', 'David ...
# 4                                          ['Paul King']
# ...                                                  ...
# 12012                                     ['Adam Green']
# 12013                  ['Henry Joost', 'Ariel Schulman']
# 12014                                      ['Rick Bota']
# 12015                                     ['Joel Zwick']
# 12016                                 ['Otto Preminger']
#
# [12017 rows x 21 columns]

# %% [markdown]
# ## Étape 2 : Reformatage de certaines variables
#
# Nous pouvons remarquer maintenant que certaines variables (belongs_to_collection par exemple) sont formatées de façon un peu complexes : ce sont des chaînes de caractères, ressemblant à des dictionnaires. Pour ces variables, seule une partie de cette chaîne de carcatères nous intéresse, en général ce qui suit le terme 'name'. Pour récupérer seulement cette partie là, la méthode pour laquelle nous avons opté est de passer par les Regular Expressions (le module re), ne pouvant pas utiliser les méthodes associées aux dictionnaires.
#
# Nous avons pris garde pour cahcune des vaariables de traiter le cas où la valeur était NaN, même si la variable 'belongs_to_collection' était la seule à en avoir.

# %%
type(base['belongs_to_collection'][2])
# Out:
# str

# %%
def extract_name(x):
    if pd.notna(x) and isinstance(x, str):
        match = re.search("'name':\s*'([^']+)'", str(x))
        return match.group(1) if match else None
    else:
        return None

base['collection_name'] = base['belongs_to_collection'].apply(extract_name)

# %%
base = base.drop(['belongs_to_collection'], axis=1)
base
# Out:
#        adult     budget                                             genres  \
# 0      False   40000000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 1      False  200000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 2      False   95000000  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 3      False          0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4      False  125000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...      ...        ...                                                ...
# 12012  False          0  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 12013  False          0  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 12014  False    4000000  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 12015  False   45000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 12016  False    1000000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#             id     imdb_id original_language               original_title  \
# 0       897087  tt15744298                en                    Freelance
# 1       466420   tt5537002                en   Killers of the Flower Moon
# 2       901362  tt14362112                en         Trolls Band Together
# 3      1075794   tt5755238                en                          Leo
# 4       787699   tt6166392                en                        Wonka
# ...        ...         ...               ...                          ...
# 12012   472338   tt5534434                en               Victor Crowley
# 12013   605116   tt7550000                en                Project Power
# 12014    17455   tt0337636                en           Hellraiser: Deader
# 12015    15045   tt0396592                en                   Fat Albert
# 12016      541   tt0048347                en  The Man with the Golden Arm
#
#                                                 overview popularity  \
# 0      An ex-special forces operative takes a job to ...   2367.027
# 1      When oil is discovered in 1920s Oklahoma under...   1806.389
# 2      When Branch's brother, Floyd, is kidnapped for...   1560.713
# 3      Jaded 74-year-old lizard Leo has been stuck in...    1303.89
# 4      Willy Wonka – chock-full of ideas and determin...   1256.256
# ...                                                  ...        ...
# 12012  Ten years ago, over forty people were brutally...     30.668
# 12013  An ex-soldier, a teen and a cop collide in New...      30.55
# 12014  In London, after investigating crack addicted ...     30.664
# 12015  Animated character Fat Albert emerges from his...     30.536
# 12016  A junkie must face his true self to kick his d...     30.664
#
#                                     production_companies  ... release_date  \
# 0      [{'id': 89171, 'logo_path': '/c3ttVfx0itQzk2vO...  ...   2023-10-05
# 1      [{'id': 194232, 'logo_path': '/oE7H93u8sy5vvW5...  ...   2023-10-18
# 2      [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...  ...   2023-10-12
# 3      [{'id': 878, 'logo_path': '/e2AZdsQdkhN0qJhoN4...  ...   2023-11-17
# 4      [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...  ...   2023-12-06
# ...                                                  ...  ...          ...
# 12012  [{'id': 3960, 'logo_path': None, 'name': 'Arie...  ...   2017-09-12
# 12013  [{'id': 102118, 'logo_path': None, 'name': 'Sc...  ...   2020-08-14
# 12014  [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...  ...   2005-06-07
# 12015  [{'id': 89719, 'logo_path': None, 'name': 'Cul...  ...   2004-12-25
# 12016  [{'id': 3266, 'logo_path': None, 'name': 'Otto...  ...   1955-12-26
#
#            revenue  runtime  \
# 0        8000000.0    108.0
# 1      155500000.0    206.0
# 2      173800000.0     92.0
# 3              0.0    102.0
# 4       43200000.0    117.0
# ...            ...      ...
# 12012          0.0     83.0
# 12013          0.0    113.0
# 12014          0.0     88.0
# 12015   48600000.0     93.0
# 12016    4350000.0    119.0
#
#                                         spoken_languages  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...
# 2      [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      [{'english_name': 'English', 'iso_639_1': 'en'...
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...
# ...                                                  ...
# 12012  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12013  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12014  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12015  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12016  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                  tagline  \
# 0                            Retirement didn't suit him.
# 1             Greed is an animal that hungers for blood.
# 2                There are some new trolls on the block.
# 3                            Breaking out this November.
# 4      Every good thing in this world started with a ...
# ...                                                  ...
# 12012                                Return to his Swamp
# 12013  What would you risk for five minutes of pure p...
# 12014                  The Latest. Most Terrifying Evil.
# 12015                                     Hey! Hey! Hey!
# 12016  An 'untouchable' theme…an unusual motion picture!
#
#                              title vote_average  vote_count  \
# 0                        Freelance        6.419       192.0
# 1       Killers of the Flower Moon        7.711      1258.0
# 2             Trolls Band Together        7.204       324.0
# 3                              Leo        7.560       497.0
# 4                            Wonka        7.000        62.0
# ...                            ...          ...         ...
# 12012               Victor Crowley        5.700       235.0
# 12013                Project Power        6.474      2666.0
# 12014           Hellraiser: Deader        4.600       292.0
# 12015                   Fat Albert        5.100       242.0
# 12016  The Man with the Golden Arm        7.200       200.0
#
#                                                directors  \
# 0                                       ['Pierre Morel']
# 1                                    ['Martin Scorsese']
# 2                                         ['Walt Dohrn']
# 3      ['Robert Smigel', 'Robert Marianetti', 'David ...
# 4                                          ['Paul King']
# ...                                                  ...
# 12012                                     ['Adam Green']
# 12013                  ['Henry Joost', 'Ariel Schulman']
# 12014                                      ['Rick Bota']
# 12015                                     ['Joel Zwick']
# 12016                                 ['Otto Preminger']
#
#              collection_name
# 0                       None
# 1                       None
# 2      The Trolls Collection
# 3                       None
# 4                       None
# ...                      ...
# 12012     Hatchet Collection
# 12013                   None
# 12014  Hellraiser Collection
# 12015                   None
# 12016                   None
#
# [12017 rows x 21 columns]

# %% [markdown]
# Pour les autres variables, les chaînes de caractères se complexifiaient un peu, puisqu'il y pouvait y avoir plusieurs accolades à la suite. Nous avons donc modifié un peu la fonction que nous avons ensuite appliquée à la colonne.

# %%
def extract_genres(x):
    try:
        return [re.search("'name':\s*'([^']+)'", match.group()).group(1) for match in re.finditer("{.*?'name':\s*'([^']+)'", str(x))]
    except (AttributeError, TypeError):
        return None

base['genres_list'] = base['genres'].apply(extract_genres)

# %%
base['countries_prod'] = base['production_countries'].apply(extract_genres)
base
# Out:
#        adult     budget                                             genres  \
# 0      False   40000000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 1      False  200000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 2      False   95000000  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 3      False          0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4      False  125000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...      ...        ...                                                ...
# 12012  False          0  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 12013  False          0  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 12014  False    4000000  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 12015  False   45000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 12016  False    1000000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#             id     imdb_id original_language               original_title  \
# 0       897087  tt15744298                en                    Freelance
# 1       466420   tt5537002                en   Killers of the Flower Moon
# 2       901362  tt14362112                en         Trolls Band Together
# 3      1075794   tt5755238                en                          Leo
# 4       787699   tt6166392                en                        Wonka
# ...        ...         ...               ...                          ...
# 12012   472338   tt5534434                en               Victor Crowley
# 12013   605116   tt7550000                en                Project Power
# 12014    17455   tt0337636                en           Hellraiser: Deader
# 12015    15045   tt0396592                en                   Fat Albert
# 12016      541   tt0048347                en  The Man with the Golden Arm
#
#                                                 overview popularity  \
# 0      An ex-special forces operative takes a job to ...   2367.027
# 1      When oil is discovered in 1920s Oklahoma under...   1806.389
# 2      When Branch's brother, Floyd, is kidnapped for...   1560.713
# 3      Jaded 74-year-old lizard Leo has been stuck in...    1303.89
# 4      Willy Wonka – chock-full of ideas and determin...   1256.256
# ...                                                  ...        ...
# 12012  Ten years ago, over forty people were brutally...     30.668
# 12013  An ex-soldier, a teen and a cop collide in New...      30.55
# 12014  In London, after investigating crack addicted ...     30.664
# 12015  Animated character Fat Albert emerges from his...     30.536
# 12016  A junkie must face his true self to kick his d...     30.664
#
#                                     production_companies  ... runtime  \
# 0      [{'id': 89171, 'logo_path': '/c3ttVfx0itQzk2vO...  ...   108.0
# 1      [{'id': 194232, 'logo_path': '/oE7H93u8sy5vvW5...  ...   206.0
# 2      [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...  ...    92.0
# 3      [{'id': 878, 'logo_path': '/e2AZdsQdkhN0qJhoN4...  ...   102.0
# 4      [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...  ...   117.0
# ...                                                  ...  ...     ...
# 12012  [{'id': 3960, 'logo_path': None, 'name': 'Arie...  ...    83.0
# 12013  [{'id': 102118, 'logo_path': None, 'name': 'Sc...  ...   113.0
# 12014  [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...  ...    88.0
# 12015  [{'id': 89719, 'logo_path': None, 'name': 'Cul...  ...    93.0
# 12016  [{'id': 3266, 'logo_path': None, 'name': 'Otto...  ...   119.0
#
#                                         spoken_languages  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...
# 2      [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      [{'english_name': 'English', 'iso_639_1': 'en'...
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...
# ...                                                  ...
# 12012  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12013  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12014  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12015  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12016  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                  tagline  \
# 0                            Retirement didn't suit him.
# 1             Greed is an animal that hungers for blood.
# 2                There are some new trolls on the block.
# 3                            Breaking out this November.
# 4      Every good thing in this world started with a ...
# ...                                                  ...
# 12012                                Return to his Swamp
# 12013  What would you risk for five minutes of pure p...
# 12014                  The Latest. Most Terrifying Evil.
# 12015                                     Hey! Hey! Hey!
# 12016  An 'untouchable' theme…an unusual motion picture!
#
#                              title vote_average vote_count  \
# 0                        Freelance        6.419      192.0
# 1       Killers of the Flower Moon        7.711     1258.0
# 2             Trolls Band Together        7.204      324.0
# 3                              Leo        7.560      497.0
# 4                            Wonka        7.000       62.0
# ...                            ...          ...        ...
# 12012               Victor Crowley        5.700      235.0
# 12013                Project Power        6.474     2666.0
# 12014           Hellraiser: Deader        4.600      292.0
# 12015                   Fat Albert        5.100      242.0
# 12016  The Man with the Golden Arm        7.200      200.0
#
#                                                directors  \
# 0                                       ['Pierre Morel']
# 1                                    ['Martin Scorsese']
# 2                                         ['Walt Dohrn']
# 3      ['Robert Smigel', 'Robert Marianetti', 'David ...
# 4                                          ['Paul King']
# ...                                                  ...
# 12012                                     ['Adam Green']
# 12013                  ['Henry Joost', 'Ariel Schulman']
# 12014                                      ['Rick Bota']
# 12015                                     ['Joel Zwick']
# 12016                                 ['Otto Preminger']
#
#              collection_name                                  genres_list  \
# 0                       None                             [Action, Comedy]
# 1                       None                      [Crime, Drama, History]
# 2      The Trolls Collection  [Animation, Family, Music, Fantasy, Comedy]
# 3                       None                  [Animation, Comedy, Family]
# 4                       None                    [Comedy, Family, Fantasy]
# ...                      ...                                          ...
# 12012     Hatchet Collection                             [Comedy, Horror]
# 12013                   None             [Action, Crime, Science Fiction]
# 12014  Hellraiser Collection                  [Horror, Mystery, Thriller]
# 12015                   None                    [Comedy, Family, Fantasy]
# 12016                   None                               [Drama, Crime]
#
#                                    countries_prod
# 0                      [United States of America]
# 1                      [United States of America]
# 2                      [United States of America]
# 3           [Australia, United States of America]
# 4      [United Kingdom, United States of America]
# ...                                           ...
# 12012                  [United States of America]
# 12013                  [United States of America]
# 12014         [Romania, United States of America]
# 12015                  [United States of America]
# 12016                  [United States of America]
#
# [12017 rows x 23 columns]

# %%
def extract_languages(x):
    try:
        return [re.search("'english_name':\s*'([^']+)'", match.group()).group(1) for match in re.finditer("{.*?'english_name':\s*'([^']+)'", str(x))]
    except (AttributeError, TypeError):
        return None

base['languages_list'] = base['spoken_languages'].apply(extract_languages)
base
# Out:
#        adult     budget                                             genres  \
# 0      False   40000000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 1      False  200000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 2      False   95000000  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 3      False          0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4      False  125000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...      ...        ...                                                ...
# 12012  False          0  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 12013  False          0  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 12014  False    4000000  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 12015  False   45000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 12016  False    1000000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#             id     imdb_id original_language               original_title  \
# 0       897087  tt15744298                en                    Freelance
# 1       466420   tt5537002                en   Killers of the Flower Moon
# 2       901362  tt14362112                en         Trolls Band Together
# 3      1075794   tt5755238                en                          Leo
# 4       787699   tt6166392                en                        Wonka
# ...        ...         ...               ...                          ...
# 12012   472338   tt5534434                en               Victor Crowley
# 12013   605116   tt7550000                en                Project Power
# 12014    17455   tt0337636                en           Hellraiser: Deader
# 12015    15045   tt0396592                en                   Fat Albert
# 12016      541   tt0048347                en  The Man with the Golden Arm
#
#                                                 overview popularity  \
# 0      An ex-special forces operative takes a job to ...   2367.027
# 1      When oil is discovered in 1920s Oklahoma under...   1806.389
# 2      When Branch's brother, Floyd, is kidnapped for...   1560.713
# 3      Jaded 74-year-old lizard Leo has been stuck in...    1303.89
# 4      Willy Wonka – chock-full of ideas and determin...   1256.256
# ...                                                  ...        ...
# 12012  Ten years ago, over forty people were brutally...     30.668
# 12013  An ex-soldier, a teen and a cop collide in New...      30.55
# 12014  In London, after investigating crack addicted ...     30.664
# 12015  Animated character Fat Albert emerges from his...     30.536
# 12016  A junkie must face his true self to kick his d...     30.664
#
#                                     production_companies  ...  \
# 0      [{'id': 89171, 'logo_path': '/c3ttVfx0itQzk2vO...  ...
# 1      [{'id': 194232, 'logo_path': '/oE7H93u8sy5vvW5...  ...
# 2      [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...  ...
# 3      [{'id': 878, 'logo_path': '/e2AZdsQdkhN0qJhoN4...  ...
# 4      [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...  ...
# ...                                                  ...  ...
# 12012  [{'id': 3960, 'logo_path': None, 'name': 'Arie...  ...
# 12013  [{'id': 102118, 'logo_path': None, 'name': 'Sc...  ...
# 12014  [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...  ...
# 12015  [{'id': 89719, 'logo_path': None, 'name': 'Cul...  ...
# 12016  [{'id': 3266, 'logo_path': None, 'name': 'Otto...  ...
#
#                                         spoken_languages  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...
# 2      [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      [{'english_name': 'English', 'iso_639_1': 'en'...
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...
# ...                                                  ...
# 12012  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12013  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12014  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12015  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12016  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                  tagline  \
# 0                            Retirement didn't suit him.
# 1             Greed is an animal that hungers for blood.
# 2                There are some new trolls on the block.
# 3                            Breaking out this November.
# 4      Every good thing in this world started with a ...
# ...                                                  ...
# 12012                                Return to his Swamp
# 12013  What would you risk for five minutes of pure p...
# 12014                  The Latest. Most Terrifying Evil.
# 12015                                     Hey! Hey! Hey!
# 12016  An 'untouchable' theme…an unusual motion picture!
#
#                              title  vote_average vote_count  \
# 0                        Freelance         6.419      192.0
# 1       Killers of the Flower Moon         7.711     1258.0
# 2             Trolls Band Together         7.204      324.0
# 3                              Leo         7.560      497.0
# 4                            Wonka         7.000       62.0
# ...                            ...           ...        ...
# 12012               Victor Crowley         5.700      235.0
# 12013                Project Power         6.474     2666.0
# 12014           Hellraiser: Deader         4.600      292.0
# 12015                   Fat Albert         5.100      242.0
# 12016  The Man with the Golden Arm         7.200      200.0
#
#                                                directors  \
# 0                                       ['Pierre Morel']
# 1                                    ['Martin Scorsese']
# 2                                         ['Walt Dohrn']
# 3      ['Robert Smigel', 'Robert Marianetti', 'David ...
# 4                                          ['Paul King']
# ...                                                  ...
# 12012                                     ['Adam Green']
# 12013                  ['Henry Joost', 'Ariel Schulman']
# 12014                                      ['Rick Bota']
# 12015                                     ['Joel Zwick']
# 12016                                 ['Otto Preminger']
#
#              collection_name                                  genres_list  \
# 0                       None                             [Action, Comedy]
# 1                       None                      [Crime, Drama, History]
# 2      The Trolls Collection  [Animation, Family, Music, Fantasy, Comedy]
# 3                       None                  [Animation, Comedy, Family]
# 4                       None                    [Comedy, Family, Fantasy]
# ...                      ...                                          ...
# 12012     Hatchet Collection                             [Comedy, Horror]
# 12013                   None             [Action, Crime, Science Fiction]
# 12014  Hellraiser Collection                  [Horror, Mystery, Thriller]
# 12015                   None                    [Comedy, Family, Fantasy]
# 12016                   None                               [Drama, Crime]
#
#                                    countries_prod  \
# 0                      [United States of America]
# 1                      [United States of America]
# 2                      [United States of America]
# 3           [Australia, United States of America]
# 4      [United Kingdom, United States of America]
# ...                                           ...
# 12012                  [United States of America]
# 12013                  [United States of America]
# 12014         [Romania, United States of America]
# 12015                  [United States of America]
# 12016                  [United States of America]
#
#                      languages_list
# 0                [English, Spanish]
# 1          [English, French, Latin]
# 2             [English, Lithuanian]
# 3                         [English]
# 4                         [English]
# ...                             ...
# 12012                     [English]
# 12013  [English, Hindi, Portuguese]
# 12014                     [English]
# 12015                     [English]
# 12016                     [English]
#
# [12017 rows x 24 columns]

# %%
def extract_production_companies(x):
    try:
        return [(match.group('name'), match.group('origin_country')) for match in re.finditer(r"'name':\s*'(?P<name>[^']+).*?'origin_country':\s*'(?P<origin_country>[^']+)'", str(x))]
    except (AttributeError, TypeError):
        return None

base['prod_companies'] = base['production_companies'].apply(extract_production_companies)
base
# Out:
#        adult     budget                                             genres  \
# 0      False   40000000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 1      False  200000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 2      False   95000000  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 3      False          0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4      False  125000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...      ...        ...                                                ...
# 12012  False          0  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 12013  False          0  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 12014  False    4000000  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 12015  False   45000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 12016  False    1000000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#             id     imdb_id original_language               original_title  \
# 0       897087  tt15744298                en                    Freelance
# 1       466420   tt5537002                en   Killers of the Flower Moon
# 2       901362  tt14362112                en         Trolls Band Together
# 3      1075794   tt5755238                en                          Leo
# 4       787699   tt6166392                en                        Wonka
# ...        ...         ...               ...                          ...
# 12012   472338   tt5534434                en               Victor Crowley
# 12013   605116   tt7550000                en                Project Power
# 12014    17455   tt0337636                en           Hellraiser: Deader
# 12015    15045   tt0396592                en                   Fat Albert
# 12016      541   tt0048347                en  The Man with the Golden Arm
#
#                                                 overview popularity  \
# 0      An ex-special forces operative takes a job to ...   2367.027
# 1      When oil is discovered in 1920s Oklahoma under...   1806.389
# 2      When Branch's brother, Floyd, is kidnapped for...   1560.713
# 3      Jaded 74-year-old lizard Leo has been stuck in...    1303.89
# 4      Willy Wonka – chock-full of ideas and determin...   1256.256
# ...                                                  ...        ...
# 12012  Ten years ago, over forty people were brutally...     30.668
# 12013  An ex-soldier, a teen and a cop collide in New...      30.55
# 12014  In London, after investigating crack addicted ...     30.664
# 12015  Animated character Fat Albert emerges from his...     30.536
# 12016  A junkie must face his true self to kick his d...     30.664
#
#                                     production_companies  ...  \
# 0      [{'id': 89171, 'logo_path': '/c3ttVfx0itQzk2vO...  ...
# 1      [{'id': 194232, 'logo_path': '/oE7H93u8sy5vvW5...  ...
# 2      [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...  ...
# 3      [{'id': 878, 'logo_path': '/e2AZdsQdkhN0qJhoN4...  ...
# 4      [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...  ...
# ...                                                  ...  ...
# 12012  [{'id': 3960, 'logo_path': None, 'name': 'Arie...  ...
# 12013  [{'id': 102118, 'logo_path': None, 'name': 'Sc...  ...
# 12014  [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...  ...
# 12015  [{'id': 89719, 'logo_path': None, 'name': 'Cul...  ...
# 12016  [{'id': 3266, 'logo_path': None, 'name': 'Otto...  ...
#
#                                                  tagline  \
# 0                            Retirement didn't suit him.
# 1             Greed is an animal that hungers for blood.
# 2                There are some new trolls on the block.
# 3                            Breaking out this November.
# 4      Every good thing in this world started with a ...
# ...                                                  ...
# 12012                                Return to his Swamp
# 12013  What would you risk for five minutes of pure p...
# 12014                  The Latest. Most Terrifying Evil.
# 12015                                     Hey! Hey! Hey!
# 12016  An 'untouchable' theme…an unusual motion picture!
#
#                              title  vote_average  vote_count  \
# 0                        Freelance         6.419       192.0
# 1       Killers of the Flower Moon         7.711      1258.0
# 2             Trolls Band Together         7.204       324.0
# 3                              Leo         7.560       497.0
# 4                            Wonka         7.000        62.0
# ...                            ...           ...         ...
# 12012               Victor Crowley         5.700       235.0
# 12013                Project Power         6.474      2666.0
# 12014           Hellraiser: Deader         4.600       292.0
# 12015                   Fat Albert         5.100       242.0
# 12016  The Man with the Golden Arm         7.200       200.0
#
#                                                directors  \
# 0                                       ['Pierre Morel']
# 1                                    ['Martin Scorsese']
# 2                                         ['Walt Dohrn']
# 3      ['Robert Smigel', 'Robert Marianetti', 'David ...
# 4                                          ['Paul King']
# ...                                                  ...
# 12012                                     ['Adam Green']
# 12013                  ['Henry Joost', 'Ariel Schulman']
# 12014                                      ['Rick Bota']
# 12015                                     ['Joel Zwick']
# 12016                                 ['Otto Preminger']
#
#              collection_name                                  genres_list  \
# 0                       None                             [Action, Comedy]
# 1                       None                      [Crime, Drama, History]
# 2      The Trolls Collection  [Animation, Family, Music, Fantasy, Comedy]
# 3                       None                  [Animation, Comedy, Family]
# 4                       None                    [Comedy, Family, Fantasy]
# ...                      ...                                          ...
# 12012     Hatchet Collection                             [Comedy, Horror]
# 12013                   None             [Action, Crime, Science Fiction]
# 12014  Hellraiser Collection                  [Horror, Mystery, Thriller]
# 12015                   None                    [Comedy, Family, Fantasy]
# 12016                   None                               [Drama, Crime]
#
#                                    countries_prod  \
# 0                      [United States of America]
# 1                      [United States of America]
# 2                      [United States of America]
# 3           [Australia, United States of America]
# 4      [United Kingdom, United States of America]
# ...                                           ...
# 12012                  [United States of America]
# 12013                  [United States of America]
# 12014         [Romania, United States of America]
# 12015                  [United States of America]
# 12016                  [United States of America]
#
#                      languages_list  \
# 0                [English, Spanish]
# 1          [English, French, Latin]
# 2             [English, Lithuanian]
# 3                         [English]
# 4                         [English]
# ...                             ...
# 12012                     [English]
# 12013  [English, Hindi, Portuguese]
# 12014                     [English]
# 12015                     [English]
# 12016                     [English]
#
#                                           prod_companies
# 0      [(Endurance Media, US), (AGC Studios, US), (Se...
# 1      [(Apple Studios, US), (Imperative Entertainmen...
# 2                           [(DreamWorks Animation, US)]
# 3      [(Happy Madison Productions, US), (Animal Logi...
# 4      [(Warner Bros. Pictures, US), (Village Roadsho...
# ...                                                  ...
# 12012                         [(ArieScope Pictures, US)]
# 12013           [(Screen Arcade, US), (Supermarché, US)]
# 12014  [(Dimension Films, US), (Stan Winston Producti...
# 12015     [(Culver Studios, US), (20th Century Fox, US)]
# 12016  [(Otto Preminger Films, US), (United Artists, ...
#
# [12017 rows x 25 columns]

# %%
base = base.drop(['genres', 'production_countries', 'production_companies', 'spoken_languages'], axis = 1)
base
# Out:
#        adult     budget       id     imdb_id original_language  \
# 0      False   40000000   897087  tt15744298                en
# 1      False  200000000   466420   tt5537002                en
# 2      False   95000000   901362  tt14362112                en
# 3      False          0  1075794   tt5755238                en
# 4      False  125000000   787699   tt6166392                en
# ...      ...        ...      ...         ...               ...
# 12012  False          0   472338   tt5534434                en
# 12013  False          0   605116   tt7550000                en
# 12014  False    4000000    17455   tt0337636                en
# 12015  False   45000000    15045   tt0396592                en
# 12016  False    1000000      541   tt0048347                en
#
#                     original_title  \
# 0                        Freelance
# 1       Killers of the Flower Moon
# 2             Trolls Band Together
# 3                              Leo
# 4                            Wonka
# ...                            ...
# 12012               Victor Crowley
# 12013                Project Power
# 12014           Hellraiser: Deader
# 12015                   Fat Albert
# 12016  The Man with the Golden Arm
#
#                                                 overview popularity  \
# 0      An ex-special forces operative takes a job to ...   2367.027
# 1      When oil is discovered in 1920s Oklahoma under...   1806.389
# 2      When Branch's brother, Floyd, is kidnapped for...   1560.713
# 3      Jaded 74-year-old lizard Leo has been stuck in...    1303.89
# 4      Willy Wonka – chock-full of ideas and determin...   1256.256
# ...                                                  ...        ...
# 12012  Ten years ago, over forty people were brutally...     30.668
# 12013  An ex-soldier, a teen and a cop collide in New...      30.55
# 12014  In London, after investigating crack addicted ...     30.664
# 12015  Animated character Fat Albert emerges from his...     30.536
# 12016  A junkie must face his true self to kick his d...     30.664
#
#       release_date      revenue  ...  \
# 0       2023-10-05    8000000.0  ...
# 1       2023-10-18  155500000.0  ...
# 2       2023-10-12  173800000.0  ...
# 3       2023-11-17          0.0  ...
# 4       2023-12-06   43200000.0  ...
# ...            ...          ...  ...
# 12012   2017-09-12          0.0  ...
# 12013   2020-08-14          0.0  ...
# 12014   2005-06-07          0.0  ...
# 12015   2004-12-25   48600000.0  ...
# 12016   1955-12-26    4350000.0  ...
#
#                                                  tagline  \
# 0                            Retirement didn't suit him.
# 1             Greed is an animal that hungers for blood.
# 2                There are some new trolls on the block.
# 3                            Breaking out this November.
# 4      Every good thing in this world started with a ...
# ...                                                  ...
# 12012                                Return to his Swamp
# 12013  What would you risk for five minutes of pure p...
# 12014                  The Latest. Most Terrifying Evil.
# 12015                                     Hey! Hey! Hey!
# 12016  An 'untouchable' theme…an unusual motion picture!
#
#                              title vote_average  vote_count  \
# 0                        Freelance        6.419       192.0
# 1       Killers of the Flower Moon        7.711      1258.0
# 2             Trolls Band Together        7.204       324.0
# 3                              Leo        7.560       497.0
# 4                            Wonka        7.000        62.0
# ...                            ...          ...         ...
# 12012               Victor Crowley        5.700       235.0
# 12013                Project Power        6.474      2666.0
# 12014           Hellraiser: Deader        4.600       292.0
# 12015                   Fat Albert        5.100       242.0
# 12016  The Man with the Golden Arm        7.200       200.0
#
#                                                directors  \
# 0                                       ['Pierre Morel']
# 1                                    ['Martin Scorsese']
# 2                                         ['Walt Dohrn']
# 3      ['Robert Smigel', 'Robert Marianetti', 'David ...
# 4                                          ['Paul King']
# ...                                                  ...
# 12012                                     ['Adam Green']
# 12013                  ['Henry Joost', 'Ariel Schulman']
# 12014                                      ['Rick Bota']
# 12015                                     ['Joel Zwick']
# 12016                                 ['Otto Preminger']
#
#              collection_name                                  genres_list  \
# 0                       None                             [Action, Comedy]
# 1                       None                      [Crime, Drama, History]
# 2      The Trolls Collection  [Animation, Family, Music, Fantasy, Comedy]
# 3                       None                  [Animation, Comedy, Family]
# 4                       None                    [Comedy, Family, Fantasy]
# ...                      ...                                          ...
# 12012     Hatchet Collection                             [Comedy, Horror]
# 12013                   None             [Action, Crime, Science Fiction]
# 12014  Hellraiser Collection                  [Horror, Mystery, Thriller]
# 12015                   None                    [Comedy, Family, Fantasy]
# 12016                   None                               [Drama, Crime]
#
#                                    countries_prod  \
# 0                      [United States of America]
# 1                      [United States of America]
# 2                      [United States of America]
# 3           [Australia, United States of America]
# 4      [United Kingdom, United States of America]
# ...                                           ...
# 12012                  [United States of America]
# 12013                  [United States of America]
# 12014         [Romania, United States of America]
# 12015                  [United States of America]
# 12016                  [United States of America]
#
#                      languages_list  \
# 0                [English, Spanish]
# 1          [English, French, Latin]
# 2             [English, Lithuanian]
# 3                         [English]
# 4                         [English]
# ...                             ...
# 12012                     [English]
# 12013  [English, Hindi, Portuguese]
# 12014                     [English]
# 12015                     [English]
# 12016                     [English]
#
#                                           prod_companies
# 0      [(Endurance Media, US), (AGC Studios, US), (Se...
# 1      [(Apple Studios, US), (Imperative Entertainmen...
# 2                           [(DreamWorks Animation, US)]
# 3      [(Happy Madison Productions, US), (Animal Logi...
# 4      [(Warner Bros. Pictures, US), (Village Roadsho...
# ...                                                  ...
# 12012                         [(ArieScope Pictures, US)]
# 12013           [(Screen Arcade, US), (Supermarché, US)]
# 12014  [(Dimension Films, US), (Stan Winston Producti...
# 12015     [(Culver Studios, US), (20th Century Fox, US)]
# 12016  [(Otto Preminger Films, US), (United Artists, ...
#
# [12017 rows x 21 columns]

# %% [markdown]
# Nous obtenons donc maintenant une base avec seulement les variables qui nous intéressent, et avec des valeurs soit sous forme de chaîne de caractères, soit numérique ou soit sous forme de liste, qui seront donc facilement exploitable. Nous la convertissons en .csv, pour pouvoir ensuite la fusionner avec la base scrappée des récompenses, grâce à la variable 'title', qui correspond à la variable 'English_title' dans la base des récompenses.

# %%
current_directory = os.getcwd()

# Ajouter le nom du fichier 
file_name = 'Movies.csv'
file_path = os.path.join(current_directory, file_name)

base.to_csv(file_path, index = False)
