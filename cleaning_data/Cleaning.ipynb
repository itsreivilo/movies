# %%
import pandas as pd
import re

# %%
base = pd.read_csv('../API/MoviesPopular.csv')
print(base.columns)
# Out:
# Index(['Unnamed: 0', 'adult', 'backdrop_path', 'belongs_to_collection',
#        'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
base = base.drop(['Unnamed: 0','backdrop_path','homepage', 'poster_path', 'video', 'status'], axis=1)

# %%
base
# Out:
#        adult                              belongs_to_collection     budget  \
# 0      False                                                NaN   40000000
# 1      False                                                NaN  200000000
# 2      False  {'id': 489724, 'name': 'The Trolls Collection'...   95000000
# 3      False                                                NaN          0
# 4      False                                                NaN  125000000
# ...      ...                                                ...        ...
# 9996   False  {'id': 124901, 'name': 'Hatchet Collection', '...          0
# 9997   False                                                NaN          0
# 9998   False  {'id': 8917, 'name': 'Hellraiser Collection', ...    4000000
# 9999   False                                                NaN   45000000
# 10000  False                                                NaN    1000000
#
#                                                   genres       id     imdb_id  \
# 0      [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...   897087  tt15744298
# 1      [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...   466420   tt5537002
# 2      [{'id': 16, 'name': 'Animation'}, {'id': 10751...   901362  tt14362112
# 3      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  1075794   tt5755238
# 4      [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...   787699   tt6166392
# ...                                                  ...      ...         ...
# 9996   [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...   472338   tt5534434
# 9997   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...   605116   tt7550000
# 9998   [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...    17455   tt0337636
# 9999   [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...    15045   tt0396592
# 10000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...      541   tt0048347
#
#       original_language               original_title  \
# 0                    en                    Freelance
# 1                    en   Killers of the Flower Moon
# 2                    en         Trolls Band Together
# 3                    en                          Leo
# 4                    en                        Wonka
# ...                 ...                          ...
# 9996                 en               Victor Crowley
# 9997                 en                Project Power
# 9998                 en           Hellraiser: Deader
# 9999                 en                   Fat Albert
# 10000                en  The Man with the Golden Arm
#
#                                                 overview popularity  \
# 0      An ex-special forces operative takes a job to ...   2367.027
# 1      When oil is discovered in 1920s Oklahoma under...   1806.389
# 2      When Branch's brother, Floyd, is kidnapped for...   1560.713
# 3      Jaded 74-year-old lizard Leo has been stuck in...    1303.89
# 4      Willy Wonka – chock-full of ideas and determin...   1256.256
# ...                                                  ...        ...
# 9996   Ten years ago, over forty people were brutally...     30.668
# 9997   An ex-soldier, a teen and a cop collide in New...      30.55
# 9998   In London, after investigating crack addicted ...     30.664
# 9999   Animated character Fat Albert emerges from his...     30.536
# 10000  A junkie must face his true self to kick his d...     30.664
#
#                                     production_companies  \
# 0      [{'id': 89171, 'logo_path': '/c3ttVfx0itQzk2vO...
# 1      [{'id': 194232, 'logo_path': '/oE7H93u8sy5vvW5...
# 2      [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...
# 3      [{'id': 878, 'logo_path': '/e2AZdsQdkhN0qJhoN4...
# 4      [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...
# ...                                                  ...
# 9996   [{'id': 3960, 'logo_path': None, 'name': 'Arie...
# 9997   [{'id': 102118, 'logo_path': None, 'name': 'Sc...
# 9998   [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...
# 9999   [{'id': 89719, 'logo_path': None, 'name': 'Cul...
# 10000  [{'id': 3266, 'logo_path': None, 'name': 'Otto...
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   2023-10-05
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   2023-10-18
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   2023-10-12
# 3      [{'iso_3166_1': 'AU', 'name': 'Australia'}, {'...   2023-11-17
# 4      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2023-12-06
# ...                                                  ...          ...
# 9996   [{'iso_3166_1': 'US', 'name': 'United States o...   2017-09-12
# 9997   [{'iso_3166_1': 'US', 'name': 'United States o...   2020-08-14
# 9998   [{'iso_3166_1': 'RO', 'name': 'Romania'}, {'is...   2005-06-07
# 9999   [{'iso_3166_1': 'US', 'name': 'United States o...   2004-12-25
# 10000  [{'iso_3166_1': 'US', 'name': 'United States o...   1955-12-26
#
#            revenue  runtime  \
# 0        8000000.0    108.0
# 1      155500000.0    206.0
# 2      173800000.0     92.0
# 3              0.0    102.0
# 4       43200000.0    117.0
# ...            ...      ...
# 9996           0.0     83.0
# 9997           0.0    113.0
# 9998           0.0     88.0
# 9999    48600000.0     93.0
# 10000    4350000.0    119.0
#
#                                         spoken_languages  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...
# 2      [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      [{'english_name': 'English', 'iso_639_1': 'en'...
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...
# ...                                                  ...
# 9996   [{'english_name': 'English', 'iso_639_1': 'en'...
# 9997   [{'english_name': 'English', 'iso_639_1': 'en'...
# 9998   [{'english_name': 'English', 'iso_639_1': 'en'...
# 9999   [{'english_name': 'English', 'iso_639_1': 'en'...
# 10000  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                  tagline  \
# 0                            Retirement didn't suit him.
# 1             Greed is an animal that hungers for blood.
# 2                There are some new trolls on the block.
# 3                            Breaking out this November.
# 4      Every good thing in this world started with a ...
# ...                                                  ...
# 9996                                 Return to his Swamp
# 9997   What would you risk for five minutes of pure p...
# 9998                   The Latest. Most Terrifying Evil.
# 9999                                      Hey! Hey! Hey!
# 10000  An 'untouchable' theme…an unusual motion picture!
#
#                              title  vote_average  vote_count
# 0                        Freelance         6.419       192.0
# 1       Killers of the Flower Moon         7.711      1258.0
# 2             Trolls Band Together         7.204       324.0
# 3                              Leo         7.560       497.0
# 4                            Wonka         7.000        62.0
# ...                            ...           ...         ...
# 9996                Victor Crowley         5.700       235.0
# 9997                 Project Power         6.474      2666.0
# 9998            Hellraiser: Deader         4.600       292.0
# 9999                    Fat Albert         5.100       242.0
# 10000  The Man with the Golden Arm         7.200       200.0
#
# [10001 rows x 20 columns]

# %%
type(base['belongs_to_collection'])
# Out:
# pandas.core.series.Series

# %%
def extract_name(x):
    if pd.notna(x) and isinstance(x, str):
        match = re.search("'name':\s*'([^']+)'", str(x))
        return match.group(1) if match else None
    else:
        return None

base['collection_name'] = base['belongs_to_collection'].apply(extract_name)

# %%
base = base.drop(['belongs_to_collection'], axis=1)
base
# Out:
#        adult     budget                                             genres  \
# 0      False   40000000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 1      False  200000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 2      False   95000000  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 3      False          0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4      False  125000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...      ...        ...                                                ...
# 9996   False          0  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 9997   False          0  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 9998   False    4000000  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 9999   False   45000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 10000  False    1000000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#             id     imdb_id original_language               original_title  \
# 0       897087  tt15744298                en                    Freelance
# 1       466420   tt5537002                en   Killers of the Flower Moon
# 2       901362  tt14362112                en         Trolls Band Together
# 3      1075794   tt5755238                en                          Leo
# 4       787699   tt6166392                en                        Wonka
# ...        ...         ...               ...                          ...
# 9996    472338   tt5534434                en               Victor Crowley
# 9997    605116   tt7550000                en                Project Power
# 9998     17455   tt0337636                en           Hellraiser: Deader
# 9999     15045   tt0396592                en                   Fat Albert
# 10000      541   tt0048347                en  The Man with the Golden Arm
#
#                                                 overview popularity  \
# 0      An ex-special forces operative takes a job to ...   2367.027
# 1      When oil is discovered in 1920s Oklahoma under...   1806.389
# 2      When Branch's brother, Floyd, is kidnapped for...   1560.713
# 3      Jaded 74-year-old lizard Leo has been stuck in...    1303.89
# 4      Willy Wonka – chock-full of ideas and determin...   1256.256
# ...                                                  ...        ...
# 9996   Ten years ago, over forty people were brutally...     30.668
# 9997   An ex-soldier, a teen and a cop collide in New...      30.55
# 9998   In London, after investigating crack addicted ...     30.664
# 9999   Animated character Fat Albert emerges from his...     30.536
# 10000  A junkie must face his true self to kick his d...     30.664
#
#                                     production_companies  \
# 0      [{'id': 89171, 'logo_path': '/c3ttVfx0itQzk2vO...
# 1      [{'id': 194232, 'logo_path': '/oE7H93u8sy5vvW5...
# 2      [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...
# 3      [{'id': 878, 'logo_path': '/e2AZdsQdkhN0qJhoN4...
# 4      [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...
# ...                                                  ...
# 9996   [{'id': 3960, 'logo_path': None, 'name': 'Arie...
# 9997   [{'id': 102118, 'logo_path': None, 'name': 'Sc...
# 9998   [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...
# 9999   [{'id': 89719, 'logo_path': None, 'name': 'Cul...
# 10000  [{'id': 3266, 'logo_path': None, 'name': 'Otto...
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   2023-10-05
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   2023-10-18
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   2023-10-12
# 3      [{'iso_3166_1': 'AU', 'name': 'Australia'}, {'...   2023-11-17
# 4      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2023-12-06
# ...                                                  ...          ...
# 9996   [{'iso_3166_1': 'US', 'name': 'United States o...   2017-09-12
# 9997   [{'iso_3166_1': 'US', 'name': 'United States o...   2020-08-14
# 9998   [{'iso_3166_1': 'RO', 'name': 'Romania'}, {'is...   2005-06-07
# 9999   [{'iso_3166_1': 'US', 'name': 'United States o...   2004-12-25
# 10000  [{'iso_3166_1': 'US', 'name': 'United States o...   1955-12-26
#
#            revenue  runtime  \
# 0        8000000.0    108.0
# 1      155500000.0    206.0
# 2      173800000.0     92.0
# 3              0.0    102.0
# 4       43200000.0    117.0
# ...            ...      ...
# 9996           0.0     83.0
# 9997           0.0    113.0
# 9998           0.0     88.0
# 9999    48600000.0     93.0
# 10000    4350000.0    119.0
#
#                                         spoken_languages  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...
# 2      [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      [{'english_name': 'English', 'iso_639_1': 'en'...
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...
# ...                                                  ...
# 9996   [{'english_name': 'English', 'iso_639_1': 'en'...
# 9997   [{'english_name': 'English', 'iso_639_1': 'en'...
# 9998   [{'english_name': 'English', 'iso_639_1': 'en'...
# 9999   [{'english_name': 'English', 'iso_639_1': 'en'...
# 10000  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                  tagline  \
# 0                            Retirement didn't suit him.
# 1             Greed is an animal that hungers for blood.
# 2                There are some new trolls on the block.
# 3                            Breaking out this November.
# 4      Every good thing in this world started with a ...
# ...                                                  ...
# 9996                                 Return to his Swamp
# 9997   What would you risk for five minutes of pure p...
# 9998                   The Latest. Most Terrifying Evil.
# 9999                                      Hey! Hey! Hey!
# 10000  An 'untouchable' theme…an unusual motion picture!
#
#                              title  vote_average  vote_count  \
# 0                        Freelance         6.419       192.0
# 1       Killers of the Flower Moon         7.711      1258.0
# 2             Trolls Band Together         7.204       324.0
# 3                              Leo         7.560       497.0
# 4                            Wonka         7.000        62.0
# ...                            ...           ...         ...
# 9996                Victor Crowley         5.700       235.0
# 9997                 Project Power         6.474      2666.0
# 9998            Hellraiser: Deader         4.600       292.0
# 9999                    Fat Albert         5.100       242.0
# 10000  The Man with the Golden Arm         7.200       200.0
#
#              collection_name
# 0                       None
# 1                       None
# 2      The Trolls Collection
# 3                       None
# 4                       None
# ...                      ...
# 9996      Hatchet Collection
# 9997                    None
# 9998   Hellraiser Collection
# 9999                    None
# 10000                   None
#
# [10001 rows x 20 columns]

# %%
def extract_genres(x):
    try:
        return [re.search("'name':\s*'([^']+)'", match.group()).group(1) for match in re.finditer("{.*?'name':\s*'([^']+)'", str(x))]
    except (AttributeError, TypeError):
        return None

base['genres_list'] = base['genres'].apply(extract_genres)

# %%
base['countries_prod'] = base['production_countries'].apply(extract_genres)
base
# Out:
#        adult     budget                                             genres  \
# 0      False   40000000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 1      False  200000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 2      False   95000000  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 3      False          0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4      False  125000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...      ...        ...                                                ...
# 9996   False          0  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 9997   False          0  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 9998   False    4000000  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 9999   False   45000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 10000  False    1000000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#             id     imdb_id original_language               original_title  \
# 0       897087  tt15744298                en                    Freelance
# 1       466420   tt5537002                en   Killers of the Flower Moon
# 2       901362  tt14362112                en         Trolls Band Together
# 3      1075794   tt5755238                en                          Leo
# 4       787699   tt6166392                en                        Wonka
# ...        ...         ...               ...                          ...
# 9996    472338   tt5534434                en               Victor Crowley
# 9997    605116   tt7550000                en                Project Power
# 9998     17455   tt0337636                en           Hellraiser: Deader
# 9999     15045   tt0396592                en                   Fat Albert
# 10000      541   tt0048347                en  The Man with the Golden Arm
#
#                                                 overview popularity  \
# 0      An ex-special forces operative takes a job to ...   2367.027
# 1      When oil is discovered in 1920s Oklahoma under...   1806.389
# 2      When Branch's brother, Floyd, is kidnapped for...   1560.713
# 3      Jaded 74-year-old lizard Leo has been stuck in...    1303.89
# 4      Willy Wonka – chock-full of ideas and determin...   1256.256
# ...                                                  ...        ...
# 9996   Ten years ago, over forty people were brutally...     30.668
# 9997   An ex-soldier, a teen and a cop collide in New...      30.55
# 9998   In London, after investigating crack addicted ...     30.664
# 9999   Animated character Fat Albert emerges from his...     30.536
# 10000  A junkie must face his true self to kick his d...     30.664
#
#                                     production_companies  ...      revenue  \
# 0      [{'id': 89171, 'logo_path': '/c3ttVfx0itQzk2vO...  ...    8000000.0
# 1      [{'id': 194232, 'logo_path': '/oE7H93u8sy5vvW5...  ...  155500000.0
# 2      [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...  ...  173800000.0
# 3      [{'id': 878, 'logo_path': '/e2AZdsQdkhN0qJhoN4...  ...          0.0
# 4      [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...  ...   43200000.0
# ...                                                  ...  ...          ...
# 9996   [{'id': 3960, 'logo_path': None, 'name': 'Arie...  ...          0.0
# 9997   [{'id': 102118, 'logo_path': None, 'name': 'Sc...  ...          0.0
# 9998   [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...  ...          0.0
# 9999   [{'id': 89719, 'logo_path': None, 'name': 'Cul...  ...   48600000.0
# 10000  [{'id': 3266, 'logo_path': None, 'name': 'Otto...  ...    4350000.0
#
#       runtime                                   spoken_languages  \
# 0       108.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1       206.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2        92.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3       102.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4       117.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...       ...                                                ...
# 9996     83.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 9997    113.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 9998     88.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 9999     93.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 10000   119.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                  tagline  \
# 0                            Retirement didn't suit him.
# 1             Greed is an animal that hungers for blood.
# 2                There are some new trolls on the block.
# 3                            Breaking out this November.
# 4      Every good thing in this world started with a ...
# ...                                                  ...
# 9996                                 Return to his Swamp
# 9997   What would you risk for five minutes of pure p...
# 9998                   The Latest. Most Terrifying Evil.
# 9999                                      Hey! Hey! Hey!
# 10000  An 'untouchable' theme…an unusual motion picture!
#
#                              title vote_average vote_count  \
# 0                        Freelance        6.419      192.0
# 1       Killers of the Flower Moon        7.711     1258.0
# 2             Trolls Band Together        7.204      324.0
# 3                              Leo        7.560      497.0
# 4                            Wonka        7.000       62.0
# ...                            ...          ...        ...
# 9996                Victor Crowley        5.700      235.0
# 9997                 Project Power        6.474     2666.0
# 9998            Hellraiser: Deader        4.600      292.0
# 9999                    Fat Albert        5.100      242.0
# 10000  The Man with the Golden Arm        7.200      200.0
#
#              collection_name                                  genres_list  \
# 0                       None                             [Action, Comedy]
# 1                       None                      [Crime, Drama, History]
# 2      The Trolls Collection  [Animation, Family, Music, Fantasy, Comedy]
# 3                       None                  [Animation, Comedy, Family]
# 4                       None                    [Comedy, Family, Fantasy]
# ...                      ...                                          ...
# 9996      Hatchet Collection                             [Comedy, Horror]
# 9997                    None             [Action, Crime, Science Fiction]
# 9998   Hellraiser Collection                  [Horror, Mystery, Thriller]
# 9999                    None                    [Comedy, Family, Fantasy]
# 10000                   None                               [Drama, Crime]
#
#                                    countries_prod
# 0                      [United States of America]
# 1                      [United States of America]
# 2                      [United States of America]
# 3           [Australia, United States of America]
# 4      [United Kingdom, United States of America]
# ...                                           ...
# 9996                   [United States of America]
# 9997                   [United States of America]
# 9998          [Romania, United States of America]
# 9999                   [United States of America]
# 10000                  [United States of America]
#
# [10001 rows x 22 columns]

# %%
def extract_languages(x):
    try:
        return [re.search("'english_name':\s*'([^']+)'", match.group()).group(1) for match in re.finditer("{.*?'english_name':\s*'([^']+)'", str(x))]
    except (AttributeError, TypeError):
        return None

base['languages_list'] = base['spoken_languages'].apply(extract_languages)
base
# Out:
#        adult     budget                                             genres  \
# 0      False   40000000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 1      False  200000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 2      False   95000000  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 3      False          0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4      False  125000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...      ...        ...                                                ...
# 9996   False          0  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 9997   False          0  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 9998   False    4000000  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 9999   False   45000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 10000  False    1000000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#             id     imdb_id original_language               original_title  \
# 0       897087  tt15744298                en                    Freelance
# 1       466420   tt5537002                en   Killers of the Flower Moon
# 2       901362  tt14362112                en         Trolls Band Together
# 3      1075794   tt5755238                en                          Leo
# 4       787699   tt6166392                en                        Wonka
# ...        ...         ...               ...                          ...
# 9996    472338   tt5534434                en               Victor Crowley
# 9997    605116   tt7550000                en                Project Power
# 9998     17455   tt0337636                en           Hellraiser: Deader
# 9999     15045   tt0396592                en                   Fat Albert
# 10000      541   tt0048347                en  The Man with the Golden Arm
#
#                                                 overview popularity  \
# 0      An ex-special forces operative takes a job to ...   2367.027
# 1      When oil is discovered in 1920s Oklahoma under...   1806.389
# 2      When Branch's brother, Floyd, is kidnapped for...   1560.713
# 3      Jaded 74-year-old lizard Leo has been stuck in...    1303.89
# 4      Willy Wonka – chock-full of ideas and determin...   1256.256
# ...                                                  ...        ...
# 9996   Ten years ago, over forty people were brutally...     30.668
# 9997   An ex-soldier, a teen and a cop collide in New...      30.55
# 9998   In London, after investigating crack addicted ...     30.664
# 9999   Animated character Fat Albert emerges from his...     30.536
# 10000  A junkie must face his true self to kick his d...     30.664
#
#                                     production_companies  ... runtime  \
# 0      [{'id': 89171, 'logo_path': '/c3ttVfx0itQzk2vO...  ...   108.0
# 1      [{'id': 194232, 'logo_path': '/oE7H93u8sy5vvW5...  ...   206.0
# 2      [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...  ...    92.0
# 3      [{'id': 878, 'logo_path': '/e2AZdsQdkhN0qJhoN4...  ...   102.0
# 4      [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...  ...   117.0
# ...                                                  ...  ...     ...
# 9996   [{'id': 3960, 'logo_path': None, 'name': 'Arie...  ...    83.0
# 9997   [{'id': 102118, 'logo_path': None, 'name': 'Sc...  ...   113.0
# 9998   [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...  ...    88.0
# 9999   [{'id': 89719, 'logo_path': None, 'name': 'Cul...  ...    93.0
# 10000  [{'id': 3266, 'logo_path': None, 'name': 'Otto...  ...   119.0
#
#                                         spoken_languages  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...
# 2      [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      [{'english_name': 'English', 'iso_639_1': 'en'...
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...
# ...                                                  ...
# 9996   [{'english_name': 'English', 'iso_639_1': 'en'...
# 9997   [{'english_name': 'English', 'iso_639_1': 'en'...
# 9998   [{'english_name': 'English', 'iso_639_1': 'en'...
# 9999   [{'english_name': 'English', 'iso_639_1': 'en'...
# 10000  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                  tagline  \
# 0                            Retirement didn't suit him.
# 1             Greed is an animal that hungers for blood.
# 2                There are some new trolls on the block.
# 3                            Breaking out this November.
# 4      Every good thing in this world started with a ...
# ...                                                  ...
# 9996                                 Return to his Swamp
# 9997   What would you risk for five minutes of pure p...
# 9998                   The Latest. Most Terrifying Evil.
# 9999                                      Hey! Hey! Hey!
# 10000  An 'untouchable' theme…an unusual motion picture!
#
#                              title vote_average vote_count  \
# 0                        Freelance        6.419      192.0
# 1       Killers of the Flower Moon        7.711     1258.0
# 2             Trolls Band Together        7.204      324.0
# 3                              Leo        7.560      497.0
# 4                            Wonka        7.000       62.0
# ...                            ...          ...        ...
# 9996                Victor Crowley        5.700      235.0
# 9997                 Project Power        6.474     2666.0
# 9998            Hellraiser: Deader        4.600      292.0
# 9999                    Fat Albert        5.100      242.0
# 10000  The Man with the Golden Arm        7.200      200.0
#
#              collection_name                                  genres_list  \
# 0                       None                             [Action, Comedy]
# 1                       None                      [Crime, Drama, History]
# 2      The Trolls Collection  [Animation, Family, Music, Fantasy, Comedy]
# 3                       None                  [Animation, Comedy, Family]
# 4                       None                    [Comedy, Family, Fantasy]
# ...                      ...                                          ...
# 9996      Hatchet Collection                             [Comedy, Horror]
# 9997                    None             [Action, Crime, Science Fiction]
# 9998   Hellraiser Collection                  [Horror, Mystery, Thriller]
# 9999                    None                    [Comedy, Family, Fantasy]
# 10000                   None                               [Drama, Crime]
#
#                                    countries_prod  \
# 0                      [United States of America]
# 1                      [United States of America]
# 2                      [United States of America]
# 3           [Australia, United States of America]
# 4      [United Kingdom, United States of America]
# ...                                           ...
# 9996                   [United States of America]
# 9997                   [United States of America]
# 9998          [Romania, United States of America]
# 9999                   [United States of America]
# 10000                  [United States of America]
#
#                      languages_list
# 0                [English, Spanish]
# 1          [English, French, Latin]
# 2             [English, Lithuanian]
# 3                         [English]
# 4                         [English]
# ...                             ...
# 9996                      [English]
# 9997   [English, Hindi, Portuguese]
# 9998                      [English]
# 9999                      [English]
# 10000                     [English]
#
# [10001 rows x 23 columns]

# %%
def extract_production_companies(x):
    try:
        return [(match.group('name'), match.group('origin_country')) for match in re.finditer(r"'name':\s*'(?P<name>[^']+).*?'origin_country':\s*'(?P<origin_country>[^']+)'", str(x))]
    except (AttributeError, TypeError):
        return None

base['prod_companies'] = base['production_companies'].apply(extract_production_companies)
base
# Out:
#        adult     budget                                             genres  \
# 0      False   40000000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 1      False  200000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 2      False   95000000  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 3      False          0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 4      False  125000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...      ...        ...                                                ...
# 9996   False          0  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 9997   False          0  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 9998   False    4000000  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 9999   False   45000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 10000  False    1000000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#             id     imdb_id original_language               original_title  \
# 0       897087  tt15744298                en                    Freelance
# 1       466420   tt5537002                en   Killers of the Flower Moon
# 2       901362  tt14362112                en         Trolls Band Together
# 3      1075794   tt5755238                en                          Leo
# 4       787699   tt6166392                en                        Wonka
# ...        ...         ...               ...                          ...
# 9996    472338   tt5534434                en               Victor Crowley
# 9997    605116   tt7550000                en                Project Power
# 9998     17455   tt0337636                en           Hellraiser: Deader
# 9999     15045   tt0396592                en                   Fat Albert
# 10000      541   tt0048347                en  The Man with the Golden Arm
#
#                                                 overview popularity  \
# 0      An ex-special forces operative takes a job to ...   2367.027
# 1      When oil is discovered in 1920s Oklahoma under...   1806.389
# 2      When Branch's brother, Floyd, is kidnapped for...   1560.713
# 3      Jaded 74-year-old lizard Leo has been stuck in...    1303.89
# 4      Willy Wonka – chock-full of ideas and determin...   1256.256
# ...                                                  ...        ...
# 9996   Ten years ago, over forty people were brutally...     30.668
# 9997   An ex-soldier, a teen and a cop collide in New...      30.55
# 9998   In London, after investigating crack addicted ...     30.664
# 9999   Animated character Fat Albert emerges from his...     30.536
# 10000  A junkie must face his true self to kick his d...     30.664
#
#                                     production_companies  ...  \
# 0      [{'id': 89171, 'logo_path': '/c3ttVfx0itQzk2vO...  ...
# 1      [{'id': 194232, 'logo_path': '/oE7H93u8sy5vvW5...  ...
# 2      [{'id': 521, 'logo_path': '/kP7t6RwGz2AvvTkvnI...  ...
# 3      [{'id': 878, 'logo_path': '/e2AZdsQdkhN0qJhoN4...  ...
# 4      [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...  ...
# ...                                                  ...  ...
# 9996   [{'id': 3960, 'logo_path': None, 'name': 'Arie...  ...
# 9997   [{'id': 102118, 'logo_path': None, 'name': 'Sc...  ...
# 9998   [{'id': 7405, 'logo_path': '/rfnws0uY8rsNAsrLb...  ...
# 9999   [{'id': 89719, 'logo_path': None, 'name': 'Cul...  ...
# 10000  [{'id': 3266, 'logo_path': None, 'name': 'Otto...  ...
#
#                                         spoken_languages  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...
# 2      [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      [{'english_name': 'English', 'iso_639_1': 'en'...
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...
# ...                                                  ...
# 9996   [{'english_name': 'English', 'iso_639_1': 'en'...
# 9997   [{'english_name': 'English', 'iso_639_1': 'en'...
# 9998   [{'english_name': 'English', 'iso_639_1': 'en'...
# 9999   [{'english_name': 'English', 'iso_639_1': 'en'...
# 10000  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                                  tagline  \
# 0                            Retirement didn't suit him.
# 1             Greed is an animal that hungers for blood.
# 2                There are some new trolls on the block.
# 3                            Breaking out this November.
# 4      Every good thing in this world started with a ...
# ...                                                  ...
# 9996                                 Return to his Swamp
# 9997   What would you risk for five minutes of pure p...
# 9998                   The Latest. Most Terrifying Evil.
# 9999                                      Hey! Hey! Hey!
# 10000  An 'untouchable' theme…an unusual motion picture!
#
#                              title  vote_average vote_count  \
# 0                        Freelance         6.419      192.0
# 1       Killers of the Flower Moon         7.711     1258.0
# 2             Trolls Band Together         7.204      324.0
# 3                              Leo         7.560      497.0
# 4                            Wonka         7.000       62.0
# ...                            ...           ...        ...
# 9996                Victor Crowley         5.700      235.0
# 9997                 Project Power         6.474     2666.0
# 9998            Hellraiser: Deader         4.600      292.0
# 9999                    Fat Albert         5.100      242.0
# 10000  The Man with the Golden Arm         7.200      200.0
#
#              collection_name                                  genres_list  \
# 0                       None                             [Action, Comedy]
# 1                       None                      [Crime, Drama, History]
# 2      The Trolls Collection  [Animation, Family, Music, Fantasy, Comedy]
# 3                       None                  [Animation, Comedy, Family]
# 4                       None                    [Comedy, Family, Fantasy]
# ...                      ...                                          ...
# 9996      Hatchet Collection                             [Comedy, Horror]
# 9997                    None             [Action, Crime, Science Fiction]
# 9998   Hellraiser Collection                  [Horror, Mystery, Thriller]
# 9999                    None                    [Comedy, Family, Fantasy]
# 10000                   None                               [Drama, Crime]
#
#                                    countries_prod  \
# 0                      [United States of America]
# 1                      [United States of America]
# 2                      [United States of America]
# 3           [Australia, United States of America]
# 4      [United Kingdom, United States of America]
# ...                                           ...
# 9996                   [United States of America]
# 9997                   [United States of America]
# 9998          [Romania, United States of America]
# 9999                   [United States of America]
# 10000                  [United States of America]
#
#                      languages_list  \
# 0                [English, Spanish]
# 1          [English, French, Latin]
# 2             [English, Lithuanian]
# 3                         [English]
# 4                         [English]
# ...                             ...
# 9996                      [English]
# 9997   [English, Hindi, Portuguese]
# 9998                      [English]
# 9999                      [English]
# 10000                     [English]
#
#                                           prod_companies
# 0      [(Endurance Media, US), (AGC Studios, US), (Se...
# 1      [(Apple Studios, US), (Imperative Entertainmen...
# 2                           [(DreamWorks Animation, US)]
# 3      [(Happy Madison Productions, US), (Animal Logi...
# 4      [(Warner Bros. Pictures, US), (Village Roadsho...
# ...                                                  ...
# 9996                          [(ArieScope Pictures, US)]
# 9997            [(Screen Arcade, US), (Supermarché, US)]
# 9998   [(Dimension Films, US), (Stan Winston Producti...
# 9999      [(Culver Studios, US), (20th Century Fox, US)]
# 10000  [(Otto Preminger Films, US), (United Artists, ...
#
# [10001 rows x 24 columns]

# %%
base = base.drop(['genres', 'production_countries', 'production_companies', 'spoken_languages'], axis = 1)
base
# Out:
#        adult     budget       id     imdb_id original_language  \
# 0      False   40000000   897087  tt15744298                en
# 1      False  200000000   466420   tt5537002                en
# 2      False   95000000   901362  tt14362112                en
# 3      False          0  1075794   tt5755238                en
# 4      False  125000000   787699   tt6166392                en
# ...      ...        ...      ...         ...               ...
# 9996   False          0   472338   tt5534434                en
# 9997   False          0   605116   tt7550000                en
# 9998   False    4000000    17455   tt0337636                en
# 9999   False   45000000    15045   tt0396592                en
# 10000  False    1000000      541   tt0048347                en
#
#                     original_title  \
# 0                        Freelance
# 1       Killers of the Flower Moon
# 2             Trolls Band Together
# 3                              Leo
# 4                            Wonka
# ...                            ...
# 9996                Victor Crowley
# 9997                 Project Power
# 9998            Hellraiser: Deader
# 9999                    Fat Albert
# 10000  The Man with the Golden Arm
#
#                                                 overview popularity  \
# 0      An ex-special forces operative takes a job to ...   2367.027
# 1      When oil is discovered in 1920s Oklahoma under...   1806.389
# 2      When Branch's brother, Floyd, is kidnapped for...   1560.713
# 3      Jaded 74-year-old lizard Leo has been stuck in...    1303.89
# 4      Willy Wonka – chock-full of ideas and determin...   1256.256
# ...                                                  ...        ...
# 9996   Ten years ago, over forty people were brutally...     30.668
# 9997   An ex-soldier, a teen and a cop collide in New...      30.55
# 9998   In London, after investigating crack addicted ...     30.664
# 9999   Animated character Fat Albert emerges from his...     30.536
# 10000  A junkie must face his true self to kick his d...     30.664
#
#       release_date      revenue  runtime  \
# 0       2023-10-05    8000000.0    108.0
# 1       2023-10-18  155500000.0    206.0
# 2       2023-10-12  173800000.0     92.0
# 3       2023-11-17          0.0    102.0
# 4       2023-12-06   43200000.0    117.0
# ...            ...          ...      ...
# 9996    2017-09-12          0.0     83.0
# 9997    2020-08-14          0.0    113.0
# 9998    2005-06-07          0.0     88.0
# 9999    2004-12-25   48600000.0     93.0
# 10000   1955-12-26    4350000.0    119.0
#
#                                                  tagline  \
# 0                            Retirement didn't suit him.
# 1             Greed is an animal that hungers for blood.
# 2                There are some new trolls on the block.
# 3                            Breaking out this November.
# 4      Every good thing in this world started with a ...
# ...                                                  ...
# 9996                                 Return to his Swamp
# 9997   What would you risk for five minutes of pure p...
# 9998                   The Latest. Most Terrifying Evil.
# 9999                                      Hey! Hey! Hey!
# 10000  An 'untouchable' theme…an unusual motion picture!
#
#                              title  vote_average  vote_count  \
# 0                        Freelance         6.419       192.0
# 1       Killers of the Flower Moon         7.711      1258.0
# 2             Trolls Band Together         7.204       324.0
# 3                              Leo         7.560       497.0
# 4                            Wonka         7.000        62.0
# ...                            ...           ...         ...
# 9996                Victor Crowley         5.700       235.0
# 9997                 Project Power         6.474      2666.0
# 9998            Hellraiser: Deader         4.600       292.0
# 9999                    Fat Albert         5.100       242.0
# 10000  The Man with the Golden Arm         7.200       200.0
#
#              collection_name                                  genres_list  \
# 0                       None                             [Action, Comedy]
# 1                       None                      [Crime, Drama, History]
# 2      The Trolls Collection  [Animation, Family, Music, Fantasy, Comedy]
# 3                       None                  [Animation, Comedy, Family]
# 4                       None                    [Comedy, Family, Fantasy]
# ...                      ...                                          ...
# 9996      Hatchet Collection                             [Comedy, Horror]
# 9997                    None             [Action, Crime, Science Fiction]
# 9998   Hellraiser Collection                  [Horror, Mystery, Thriller]
# 9999                    None                    [Comedy, Family, Fantasy]
# 10000                   None                               [Drama, Crime]
#
#                                    countries_prod  \
# 0                      [United States of America]
# 1                      [United States of America]
# 2                      [United States of America]
# 3           [Australia, United States of America]
# 4      [United Kingdom, United States of America]
# ...                                           ...
# 9996                   [United States of America]
# 9997                   [United States of America]
# 9998          [Romania, United States of America]
# 9999                   [United States of America]
# 10000                  [United States of America]
#
#                      languages_list  \
# 0                [English, Spanish]
# 1          [English, French, Latin]
# 2             [English, Lithuanian]
# 3                         [English]
# 4                         [English]
# ...                             ...
# 9996                      [English]
# 9997   [English, Hindi, Portuguese]
# 9998                      [English]
# 9999                      [English]
# 10000                     [English]
#
#                                           prod_companies
# 0      [(Endurance Media, US), (AGC Studios, US), (Se...
# 1      [(Apple Studios, US), (Imperative Entertainmen...
# 2                           [(DreamWorks Animation, US)]
# 3      [(Happy Madison Productions, US), (Animal Logi...
# 4      [(Warner Bros. Pictures, US), (Village Roadsho...
# ...                                                  ...
# 9996                          [(ArieScope Pictures, US)]
# 9997            [(Screen Arcade, US), (Supermarché, US)]
# 9998   [(Dimension Films, US), (Stan Winston Producti...
# 9999      [(Culver Studios, US), (20th Century Fox, US)]
# 10000  [(Otto Preminger Films, US), (United Artists, ...
#
# [10001 rows x 20 columns]

# %%
base.to_csv('Movies_Clean.csv', index = False)
