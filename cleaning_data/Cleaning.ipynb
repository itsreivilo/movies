# %%
import pandas as pd

# %%
base = pd.read_csv('../API/MoviesPopular.csv')
print(base.columns)
# Out:
# Index(['Unnamed: 0', 'adult', 'backdrop_path', 'belongs_to_collection',
#        'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
base = base.drop(['Unnamed: 0','backdrop_path','homepage', 'poster_path', 'video', 'status'], axis=1)

# %%
base
# Out:
#        adult                              belongs_to_collection     budget  \
# 0      False                                                NaN   40000000
# 1      False                                                NaN  200000000
# 2      False  {'id': 489724, 'name': 'The Trolls Collection'...   95000000
# 3      False                                                NaN          0
# 4      False                                                NaN  125000000
# ...      ...                                                ...        ...
# 9996   False  {'id': 124901, 'name': 'Hatchet Collection', '...          0
# 9997   False                                                NaN          0
# 9998   False  {'id': 8917, 'name': 'Hellraiser Collection', ...    4000000
# 9999   False                                                NaN   45000000
# 10000  False                                                NaN    1000000
#
# ...

# %%
def extract_value(dictionary):
    return dictionary.get('name', None)

base['belongs_to_collection'] = base['belongs_to_collection'].apply(lambda x: extract_value(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 def extract_value(dictionary):
#       2     return dictionary.get('name', None)
# ----> 4 base['belongs_to_collection'] = base['belongs_to_collection'].apply(lambda x: extract_value(x))
#
# File /opt/mamba/lib/python3.10/site-packages/pandas/core/series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
# ...

# %%
base['belongs_to_collection'][2]
# Out:
# "{'id': 489724, 'name': 'The Trolls Collection', 'poster_path': '/i4aII37O184x7K3dC7fpF9CAfS4.jpg', 'backdrop_path': '/xtgonS6wcxK5RfnWWohYZF3mhjM.jpg'}"

# %%
import pandas as pd
import ast  


def extract_value(json_str):
    try:
        value = ast.literal_eval(json_str)
        if isinstance(value, dict):
            # Change 'desired_key' to the key you want to keep
            return value.get('name', None)
        elif isinstance(value, list):
            # Change index to the position of the value you want to keep in the list
            return value[0] if len(value) > 0 else None
        else:
            return None  # Handle other types if necessary
    except (ValueError, SyntaxError):
        return None  # Handle invalid or 

# Apply the function to the DataFrame column
base['belongs_to_collection'] = base['belongs_to_collection'].apply(lambda x: extract_value(x))

# If you want to drop the original key, you can do so using the drop method
# df = df.drop('original_key', axis=1)

# Display the modified DataFrame
print(base)
# Out:
#        adult belongs_to_collection     budget  \
# 0      False                  None   40000000
# 1      False                  None  200000000
# 2      False                  None   95000000
# 3      False                  None          0
# 4      False                  None  125000000
# ...      ...                   ...        ...
# 9996   False                  None          0
# 9997   False                  None          0
# 9998   False                  None    4000000
# 9999   False                  None   45000000
# 10000  False                  None    1000000
#
#                                                   genres       id     imdb_id  \
# 0      [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...   897087  tt15744298
# 1      [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...   466420   tt5537002
# 2      [{'id': 16, 'name': 'Animation'}, {'id': 10751...   901362  tt14362112
# 3      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  1075794   tt5755238
# ...
